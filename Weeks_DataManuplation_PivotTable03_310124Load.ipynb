# %% [markdown]
# # LEARNING - DATA PREPERATION & EDA

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
pd.crosstab(df["sex"],df["alive"])
# Out:
# alive    no  yes
# sex
# female   81  233
# male    468  109

# %%
df.groupby("sex").agg({"survived":"mean"})
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %%
df.groupby(["sex","pclass"]).agg({"survived":["count","mean"]})
# Out:
#               survived
#                  count      mean
# sex    pclass
# female 1            94  0.968085
#        2            76  0.921053
#        3           144  0.500000
# male   1           122  0.368852
#        2           108  0.157407
#        3           347  0.135447

# %%
df["fare"]<30
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: fare, Length: 891, dtype: bool

# %%
df.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
True+False
# Out:
# 1

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
True+True
# Out:
# 2

# %%
df.shape[0]
# Out:
# 891

# %%
df.isnull().sum()/df.shape[0]
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.198653
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.002245
# class          0.000000
# who            0.000000
# adult_male     0.000000
# deck           0.772166
# embark_town    0.002245
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df["age"].sum()
# Out:
# 21205.17

# %%
df["age"].count()
# Out:
# 714

# %%
df["age"].mean()
# Out:
# 29.69911764705882

# %%
df["age"].sum()/df["age"].count()
# Out:
# 29.69911764705882

# %%
df["embark_town"].value_counts()/df.shape[0]
# Out:
# embark_town
# Southampton    0.722783
# Cherbourg      0.188552
# Queenstown     0.086420
# Name: count, dtype: float64

# %%
df["sex"].value_counts()/df.shape[0]
# Out:
# sex
# male      0.647587
# female    0.352413
# Name: count, dtype: float64

# %%
df["class"].value_counts()/df.shape[0]
# Out:
# class
# Third     0.551066
# First     0.242424
# Second    0.206510
# Name: count, dtype: float64

# %%
kolonlar = ["embark_town","sex","class","who"]

# %%
for col in kolonlar:
    print(df[col].value_counts()/df.shape[0])
    print("...........")
# Out:
# embark_town
# Southampton    0.722783
# Cherbourg      0.188552
# Queenstown     0.086420
# Name: count, dtype: float64
# ...........
# sex
# male      0.647587
# female    0.352413
# Name: count, dtype: float64
# ...........
# class
# Third     0.551066
# First     0.242424
# Second    0.206510
# Name: count, dtype: float64
# ...........
# who
# man      0.602694
# woman    0.304153
# child    0.093154
# Name: count, dtype: float64
# ...........

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
num_columns = ['survived', 'age', 'sibsp', 'parch', 'fare','alive', 'alone']
cat_columns = ['pclass', 'sex','embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town','alive'] #Sütun seçme / select

# %%
df[num_columns].columns
# Out:
# Index(['survived', 'age', 'sibsp', 'parch', 'fare', 'alive', 'alone'], dtype='object')

# %%
df[cat_columns].columns
# Out:
# Index(['pclass', 'sex', 'embarked', 'class', 'who', 'adult_male', 'deck',
#        'embark_town', 'alive'],
#       dtype='object')

# %% [markdown]
# ## SECTION : PYTHON QUERIES for EDA

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
cat_columns = ['pclass', 'sex','embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town','alive']

# %%
df_yeni = df[cat_columns]
df_yeni
# Out:
#      pclass     sex embarked   class    who  adult_male deck  embark_town  \
# 0         3    male        S   Third    man        True  NaN  Southampton
# 1         1  female        C   First  woman       False    C    Cherbourg
# 2         3  female        S   Third  woman       False  NaN  Southampton
# 3         1  female        S   First  woman       False    C  Southampton
# 4         3    male        S   Third    man        True  NaN  Southampton
# ..      ...     ...      ...     ...    ...         ...  ...          ...
# 886       2    male        S  Second    man        True  NaN  Southampton
# 887       1  female        S   First  woman       False    B  Southampton
# 888       3  female        S   Third  woman       False  NaN  Southampton
# 889       1    male        C   First    man        True    C    Cherbourg
# 890       3    male        Q   Third    man        True  NaN   Queenstown
#
#     alive
# 0      no
# 1     yes
# 2     yes
# 3     yes
# 4      no
# ...

# %%
for col in df_yeni.columns:
    print("----")
    print(df[col].value_counts()/df.shape[0])
# Out:
# ----
# pclass
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: count, dtype: float64
# ----
# sex
# male      0.647587
# female    0.352413
# Name: count, dtype: float64
# ----
# embarked
# S    0.722783
# C    0.188552
# Q    0.086420
# Name: count, dtype: float64
# ----
# class
# Third     0.551066
# First     0.242424
# Second    0.206510
# Name: count, dtype: float64
# ----
# who
# man      0.602694
# woman    0.304153
# child    0.093154
# Name: count, dtype: float64
# ----
# adult_male
# True     0.602694
# False    0.397306
# Name: count, dtype: float64
# ----
# deck
# C    0.066218
# B    0.052750
# D    0.037037
# E    0.035915
# A    0.016835
# F    0.014590
# G    0.004489
# Name: count, dtype: float64
# ----
# embark_town
# Southampton    0.722783
# Cherbourg      0.188552
# Queenstown     0.086420
# Name: count, dtype: float64
# ----
# alive
# no     0.616162
# yes    0.383838
# Name: count, dtype: float64

# %%
def miuul(dataframe):
    for col in dataframe.columns:
        print("----")
        print(dataframe[col].value_counts()/dataframe.shape[0])

# %%
miuul(df_yeni)
# Out:
# ----
# pclass
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: count, dtype: float64
# ----
# sex
# male      0.647587
# female    0.352413
# Name: count, dtype: float64
# ----
# embarked
# S    0.722783
# C    0.188552
# Q    0.086420
# Name: count, dtype: float64
# ----
# class
# Third     0.551066
# First     0.242424
# Second    0.206510
# Name: count, dtype: float64
# ----
# who
# man      0.602694
# woman    0.304153
# child    0.093154
# Name: count, dtype: float64
# ----
# adult_male
# True     0.602694
# False    0.397306
# Name: count, dtype: float64
# ----
# deck
# C    0.066218
# B    0.052750
# D    0.037037
# E    0.035915
# A    0.016835
# F    0.014590
# G    0.004489
# Name: count, dtype: float64
# ----
# embark_town
# Southampton    0.722783
# Cherbourg      0.188552
# Queenstown     0.086420
# Name: count, dtype: float64
# ----
# alive
# no     0.616162
# yes    0.383838
# Name: count, dtype: float64

# %%
df_ = pd.read_csv("TelcoCustomer.csv",delimiter=";")
df_.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df_ = pd.read_csv("TelcoCustomer.csv",delimiter=";")
#       2 df_.head()
#
# File E:\AnacondaFiles\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df_ = pd.read_csv("TelcoCustomer.csv", delimiter=";")
df = df_.copy() # Verinin Kopyasini olurstur
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df_ = pd.read_csv("TelcoCustomer.csv", delimiter=";")
#       2 df = df_.copy() # Verinin Kopyasini olurstur
#       3 df.head()
#
# ...

# %%
df.shape
# Out:
# (891, 15)

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.values[0]
# Out:
# array([0, 3, 'male', 22.0, 1, 0, 7.25, 'S', 'Third', 'man', True, nan,
#        'Southampton', 'no', False], dtype=object)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
secilen_kolonlar = ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'PhoneService',  'Churn']

# %%
miuul(df[secilen_kolonlar])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 miuul(df[secilen_kolonlar])
#
# File E:\AnacondaFiles\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File E:\AnacondaFiles\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
for col in df.columns:
    print(col)
# Out:
# survived
# pclass
# sex
# age
# sibsp
# parch
# fare
# embarked
# class
# who
# adult_male
# deck
# embark_town
# alive
# alone

# %%
df.Churn.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12608\3567862198.py in ?()
# ----> 1 df.Churn.value_counts()
#
# E:\AnacondaFiles\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Churn'

# %% [markdown]
# ### New Column

# %%
df["miuul"] = 4
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  miuul
# 0    man        True  NaN  Southampton    no  False      4
# 1  woman       False    C    Cherbourg   yes  False      4
# 2  woman       False  NaN  Southampton   yes   True      4
# 3  woman       False    C  Southampton   yes  False      4
# 4    man        True  NaN  Southampton    no   True      4

# %%
df["yeni"] = 1
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  miuul  yeni
# 0    man        True  NaN  Southampton    no  False      4     1
# 1  woman       False    C    Cherbourg   yes  False      4     1
# 2  woman       False  NaN  Southampton   yes   True      4     1
# 3  woman       False    C  Southampton   yes  False      4     1
# 4    man        True  NaN  Southampton    no   True      4     1

# %%
df["yeni"] = 2
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  miuul  yeni
# 0    man        True  NaN  Southampton    no  False      4     2
# 1  woman       False    C    Cherbourg   yes  False      4     2
# 2  woman       False  NaN  Southampton   yes   True      4     2
# 3  woman       False    C  Southampton   yes  False      4     2
# 4    man        True  NaN  Southampton    no   True      4     2

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  miuul  yeni
# 0    man        True  NaN  Southampton    no  False      4     2
# 1  woman       False    C    Cherbourg   yes  False      4     2
# 2  woman       False  NaN  Southampton   yes   True      4     2
# 3  woman       False    C  Southampton   yes  False      4     2
# 4    man        True  NaN  Southampton    no   True      4     2

# %% [markdown]
# ### LOC ...

# %%
df.loc[df['Churn'] == 'Yes', 'NewChurn'] = 1
df.loc[df['Churn'] == 'No', 'NewChurn'] = 0
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File E:\AnacondaFiles\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File E:\AnacondaFiles\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File E:\AnacondaFiles\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Churn'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df
# Out:
#            survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0                 0       3    male  22.0      1      0   7.2500        S
# 1                 1       1  female  38.0      1      0  71.2833        C
# 2                 1       3  female  26.0      0      0   7.9250        S
# 3                 1       1  female  35.0      1      0  53.1000        S
# 4                 0       3    male  35.0      0      0   8.0500        S
# ...             ...     ...     ...   ...    ...    ...      ...      ...
# 888               0       3  female   NaN      1      2  23.4500        S
# 889               1       1    male  26.0      0      0  30.0000        C
# 890               0       3    male  32.0      0      0   7.7500        Q
# 891              16      16      16  16.0     16     16  16.0000       16
# NewColumn         8       8       8   8.0      8      8   8.0000        8
#
#            class    who adult_male deck  embark_town alive  alone  miuul  \
# ...

# %%
df
# Out:
#            survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0                 0       3    male  22.0      1      0   7.2500        S
# 1                 1       1  female  38.0      1      0  71.2833        C
# 2                 1       3  female  26.0      0      0   7.9250        S
# 3                 1       1  female  35.0      1      0  53.1000        S
# 4                 0       3    male  35.0      0      0   8.0500        S
# ...             ...     ...     ...   ...    ...    ...      ...      ...
# 888               0       3  female   NaN      1      2  23.4500        S
# 889               1       1    male  26.0      0      0  30.0000        C
# 890               0       3    male  32.0      0      0   7.7500        Q
# 891              16      16      16  16.0     16     16  16.0000       16
# NewColumn         8       8       8   8.0      8      8   8.0000        8
#
#            class    who adult_male deck  embark_town alive  alone  miuul  \
# ...

# %%
df.loc[df['alone']== "False" , 'NewColumn2'] = 0
df.loc[df['alone']== "True" , 'NewColumn2'] = 1
df
# Out:
#            survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0                 0       3    male  22.0      1      0   7.2500        S
# 1                 1       1  female  38.0      1      0  71.2833        C
# 2                 1       3  female  26.0      0      0   7.9250        S
# 3                 1       1  female  35.0      1      0  53.1000        S
# 4                 0       3    male  35.0      0      0   8.0500        S
# ...             ...     ...     ...   ...    ...    ...      ...      ...
# 888               0       3  female   NaN      1      2  23.4500        S
# 889               1       1    male  26.0      0      0  30.0000        C
# 890               0       3    male  32.0      0      0   7.7500        Q
# 891              16      16      16  16.0     16     16  16.0000       16
# NewColumn         8       8       8   8.0      8      8   8.0000        8
#
#            class    who adult_male deck  embark_town alive  alone  miuul  \
# ...

# %%
pd.crosstab(df.Churn,df.NewChurn)
# Out:
# NewChurn   0.0   1.0
# Churn
# No        5174     0
# Yes          0  1869

# %% [markdown]
# ### EDA DEVAM

# %%
df["gender"].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
#
#   StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# 0              No  Month-to-month              Yes  Electronic check
# 1              No        One year               No      Mailed check
#
#   MonthlyCharges TotalCharges Churn  yeni NewChurn
# 0          29.85        29.85    No     2      0.0
# 1          56.95       1889.5    No     2      0.0
#
# [2 rows x 23 columns]

# %%
df.groupby("gender").agg({"gender":"count"})
# Out:
#         gender
# gender
# Female    3488
# Male      3555

# %%
df["NewChurn"].count()
# Out:
# 7043

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
type(df["NewChurn"].value_counts())
# Out:
# pandas.core.series.Series

# %%
df.groupby(["gender","Partner"]).agg({"Churn":"count"})
# Out:
#                 Churn
# gender Partner
# Female No        1800
#        Yes       1688
# Male   No        1841
#        Yes       1714

# %%
df.groupby(["gender","Partner"]).agg({"NewChurn":"mean"})
# Out:
#                 NewChurn
# gender Partner
# Female No       0.344444
#        Yes      0.188981
# Male   No       0.315046
#        Yes      0.204201

# %%
df.groupby(["gender","Partner"]).agg({"MonthlyCharges":"mean"})
# Out:
#                 MonthlyCharges
# gender Partner
# Female No            63.874111
#        Yes           66.622630
# Male   No            60.058854
#        Yes           68.912398

# %%
df.groupby(["gender","Partner","MultipleLines"]).agg({"MonthlyCharges":"mean"})
# Out:
#                                  MonthlyCharges
# gender Partner MultipleLines
# Female No      No                     55.858359
#                No phone service       39.853297
#                Yes                    82.093268
#        Yes     No                     53.049230
#                No phone service       45.281879
#                Yes                    82.224061
# Male   No      No                     51.502344
#                No phone service       39.252646
#                Yes                    80.272611
#        Yes     No                     57.049281
#                No phone service       44.718827
#                Yes                    83.106359

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df.groupby(["gender","Partner"]).agg({"MonthlyCharges":["count","mean"]})
# Out:
#                MonthlyCharges
#                         count       mean
# gender Partner
# Female No                1800  63.874111
#        Yes               1688  66.622630
# Male   No                1841  60.058854
#        Yes               1714  68.912398

# %%
df.groupby(["Churn"]).agg({"Churn":"count"})
# Out:
#        Churn
# Churn
# No      5174
# Yes     1869

# %%
df.groupby(["gender","Contract","Churn"]).agg({"Churn":"count"})
# Out:
#                              Churn
# gender Contract       Churn
# Female Month-to-month No      1083
#                       Yes      842
#        One year       No       643
#                       Yes       75
#        Two year       No       823
#                       Yes       22
# Male   Month-to-month No      1137
#                       Yes      813
#        One year       No       664
#                       Yes       91
#        Two year       No       824
#                       Yes       26

# %%
df.groupby(["gender","Contract"]).agg({"MonthlyCharges":"mean"}).index
# Out:
# MultiIndex([('Female', 'Month-to-month'),
#             ('Female',       'One year'),
#             ('Female',       'Two year'),
#             (  'Male', 'Month-to-month'),
#             (  'Male',       'One year'),
#             (  'Male',       'Two year')],
#            names=['gender', 'Contract'])

# %%
df.groupby(["gender","Contract"]).agg({"MonthlyCharges":"mean"}).reset_index()
# Out:
#    gender        Contract  MonthlyCharges
# 0  Female  Month-to-month       66.652623
# 1  Female        One year       66.841643
# 2  Female        Two year       60.513373
# 3    Male  Month-to-month       66.147615
# 4    Male        One year       63.343444
# 5    Male        Two year       61.025941

# %%
df.groupby(["gender","Contract","StreamingTV"]).agg({"MonthlyCharges":"mean"}).reset_index()
# Out:
#     gender        Contract          StreamingTV  MonthlyCharges
# 0   Female  Month-to-month                   No       65.574486
# 1   Female  Month-to-month  No internet service       20.413477
# 2   Female  Month-to-month                  Yes       86.618673
# 3   Female        One year                   No       65.922687
# 4   Female        One year  No internet service       20.899401
# 5   Female        One year                  Yes       91.165586
# 6   Female        Two year                   No       67.213043
# 7   Female        Two year  No internet service       21.770525
# 8   Female        Two year                  Yes       90.874021
# 9     Male  Month-to-month                   No       64.290746
# 10    Male  Month-to-month  No internet service       20.405784
# 11    Male  Month-to-month                  Yes       87.955462
# 12    Male        One year                   No       65.871087
# 13    Male        One year  No internet service       20.751777
# ...

# %%
df[df["gender"]=="Female"].groupby(["gender","Contract"]).agg({"MonthlyCharges":"mean"})
# Out:
#                        MonthlyCharges
# gender Contract
# Female Month-to-month       66.652623
#        One year             66.841643
#        Two year             60.513373

# %%
df[df["gender"]=="Female"].groupby(["Churn","Contract"]).agg({"MonthlyCharges":"mean"})
# Out:
#                       MonthlyCharges
# Churn Contract
# No    Month-to-month       61.423915
#       One year             64.346890
#       Two year             59.886634
# Yes   Month-to-month       73.377910
#       One year             88.230000
#       Two year             83.959091

# %%
df[df["gender"]=="Female"].groupby(["Churn","Contract"]).agg({"MonthlyCharges":"mean"}).T
# Out:
# Churn                      No                                 Yes           \
# Contract       Month-to-month  One year   Two year Month-to-month One year
# MonthlyCharges      61.423915  64.34689  59.886634       73.37791    88.23
#
# Churn
# Contract         Two year
# MonthlyCharges  83.959091

# %%
df[df["gender"]=="Female"].groupby(["Churn","Contract"]).agg({"MonthlyCharges":"mean"}).T.to_csv("ozet2_csv")

# %%
df[df["gender"]=="Female"].groupby(["gender","Contract"]).agg({"MonthlyCharges":"mean"})
# Out:
#                        MonthlyCharges
# gender Contract
# Female Month-to-month       66.652623
#        One year             66.841643
#        Two year             60.513373

# %%
df_yeni = df.groupby(["gender","Contract"]).agg({"MonthlyCharges":["count","mean"]})

# %%
df_yeni
# Out:
#                       MonthlyCharges
#                                count       mean
# gender Contract
# Female Month-to-month           1925  66.652623
#        One year                  718  66.841643
#        Two year                  845  60.513373
# Male   Month-to-month           1950  66.147615
#        One year                  755  63.343444
#        Two year                  850  61.025941

# %%
#df_yeni.index

# %%
df.groupby(["gender","Contract"]).agg({"MonthlyCharges":["count","mean"]})
# Out:
#                       MonthlyCharges
#                                count       mean
# gender Contract
# Female Month-to-month           1925  66.652623
#        One year                  718  66.841643
#        Two year                  845  60.513373
# Male   Month-to-month           1950  66.147615
#        One year                  755  63.343444
#        Two year                  850  61.025941

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...          No
# 4                No     Fiber optic             No  ...          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# ...

# %%
df[df["Churn"]=="No"]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 3     7795-CFOCW    Male              0      No         No      45
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# ...          ...     ...            ...     ...        ...     ...
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# ...

# %%
df[df["Churn"]=="No"]["Churn"]
# Out:
# 0       No
# 1       No
# 3       No
# 6       No
# 7       No
#         ..
# 7037    No
# 7038    No
# 7039    No
# 7040    No
# 7042    No
# Name: Churn, Length: 5174, dtype: object

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...          No
# 4                No     Fiber optic             No  ...          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# ...

# %%
df.groupby(["gender","SeniorCitizen","InternetService","Contract"]).agg({"MonthlyCharges":["mean"]})
# Out:
#                                                     MonthlyCharges
#                                                               mean
# gender SeniorCitizen InternetService Contract
# Female 0             DSL             Month-to-month      50.998286
#                                      One year            62.159608
#                                      Two year            70.441754
#                      Fiber optic     Month-to-month      86.529787
#                                      One year            98.654975
#                                      Two year           104.784091
#                      No              Month-to-month      20.403012
#                                      One year            20.861801
#                                      Two year            21.772785
#        1             DSL             Month-to-month      48.007143
#                                      One year            63.682609
# ...

# %%
df.groupby(["gender","SeniorCitizen","InternetService","Contract"]).agg({"MonthlyCharges":["mean"]}).reset_index()
# Out:
#     gender SeniorCitizen InternetService        Contract MonthlyCharges
#                                                                    mean
# 0   Female             0             DSL  Month-to-month      50.998286
# 1   Female             0             DSL        One year      62.159608
# 2   Female             0             DSL        Two year      70.441754
# 3   Female             0     Fiber optic  Month-to-month      86.529787
# 4   Female             0     Fiber optic        One year      98.654975
# 5   Female             0     Fiber optic        Two year     104.784091
# 6   Female             0              No  Month-to-month      20.403012
# 7   Female             0              No        One year      20.861801
# 8   Female             0              No        Two year      21.772785
# 9   Female             1             DSL  Month-to-month      48.007143
# 10  Female             1             DSL        One year      63.682609
# ...

# %%
dfjoin = df.groupby(["gender","SeniorCitizen","InternetService","Contract"]).agg({"MonthlyCharges":["mean"]}).reset_index()

# %%
dfjoin.head()
# Out:
#    gender SeniorCitizen InternetService        Contract MonthlyCharges
#                                                                   mean
# 0  Female             0             DSL  Month-to-month      50.998286
# 1  Female             0             DSL        One year      62.159608
# 2  Female             0             DSL        Two year      70.441754
# 3  Female             0     Fiber optic  Month-to-month      86.529787
# 4  Female             0     Fiber optic        One year      98.654975

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...          No
# 4                No     Fiber optic             No  ...          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# ...

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#df[["age"]]
# Out:
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
#Pratik Yapalım

# %%
#df[["age"]].mean()

# %%
#df["age"].fillna(45)

# %%
#df["age"].fillna(df["age"].mean())

# %%
#df["age"].fillna(df["age"].median())
# Cinsiyete göre dolduralim.. Egzersiz... :)

# %%
#df.head()

# %%
#df[df["sex"]=="male"].isnull().sum()

# %%
#df[df["sex"]=="male"]["age"].mean()

# %%
#df[df["sex"]=="female"]["age"].mean()

# %%
# df["sex"] == "male"
# df[df["sex"] == "male"]["age"].median()

# %%
# df["sex"] == "male"
df[df["sex"] == "female"]["age"].median()
# Out:
# 27.0

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df["age"].mean()
# Out:
# 29.36158249158249

# %%
df.groupby(["sex","embark_town"]).agg({"age":["mean"]})
# Out:
#                           age
#                          mean
# sex    embark_town
# female Cherbourg    28.287671
#        Queenstown   26.763889
#        Southampton  27.790640
# male   Cherbourg    31.630737
#        Queenstown   29.146341
#        Southampton  29.912132

# %%
df.groupby(["alone","sex"]).agg({"survived":["sum","count","mean"]})
# Out:
#              survived
#                   sum count      mean
# alone sex
# False female      134   188  0.712766
#       male         45   166  0.271084
# True  female       99   126  0.785714
#       male         64   411  0.155718

# %%
df.groupby(["sex","class"]).agg({"survived":["sum","count","mean"]})
# Out:
#               survived
#                    sum count      mean
# sex    class
# female First        91    94  0.968085
#        Second       70    76  0.921053
#        Third        72   144  0.500000
# male   First        45   122  0.368852
#        Second       17   108  0.157407
#        Third        47   347  0.135447

# %%
df.groupby(["alone","sex"]).agg({"survived":["sum","count","mean"]}).index
# Out:
# MultiIndex([(False, 'female'),
#             (False,   'male'),
#             ( True, 'female'),
#             ( True,   'male')],
#            names=['alone', 'sex'])

# %%
df.groupby(["alone","sex"]).agg({"survived":["sum","count","mean"]}).columns
# Out:
# MultiIndex([('survived',   'sum'),
#             ('survived', 'count'),
#             ('survived',  'mean')],
#            )

# %%
#df.groupby(by=["sex", 'pclass']).agg({"fare": "mean"}).T.to_csv("Ozet.csv",sep='|')

# %%
#df.groupby(by=["sex", 'pclass']).agg({"fare": "mean"}).T.to_csv("Ozet.csv",sep='|',decimal=',')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.sort_values(["sex","age"])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 469         1       3  female  0.75      2      1  19.2583        C  Third
# 644         1       3  female  0.75      2      1  19.2583        C  Third
# 172         1       3  female  1.00      1      1  11.1333        S  Third
# 381         1       3  female  1.00      0      2  15.7417        C  Third
# 119         0       3  female  2.00      4      2  31.2750        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 839         1       1    male   NaN      0      0  29.7000        C  First
# 846         0       3    male   NaN      8      2  69.5500        S  Third
# 859         0       3    male   NaN      0      0   7.2292        C  Third
# 868         0       3    male   NaN      0      0   9.5000        S  Third
# 878         0       3    male   NaN      0      0   7.8958        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.sort_values("fare", ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 258         1       1  female  35.0      0      0  512.3292        C   First
# 737         1       1    male  35.0      0      0  512.3292        C   First
# 679         1       1    male  36.0      0      1  512.3292        C   First
# 88          1       1  female  23.0      3      2  263.0000        S   First
# 27          0       1    male  19.0      3      2  263.0000        S   First
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 633         0       1    male   NaN      0      0    0.0000        S   First
# 413         0       2    male   NaN      0      0    0.0000        S  Second
# 822         0       1    male  38.0      0      0    0.0000        S   First
# 732         0       2    male   NaN      0      0    0.0000        S  Second
# 674         0       2    male   NaN      0      0    0.0000        S  Second
#
# ...
